# %%
import pandas as pd

# %%
# using read_csv
titanic = pd.read_csv(r"C:\Users\VEDANT\OneDrive\Desktop\Datasets\Titanic Dataset.csv")

# %%
weather = pd.read_csv(r"C:\Users\VEDANT\OneDrive\Desktop\Datasets\austin_weather.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
weather
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
weather[["Date","Events","TempHighF"]]
# Out:
#             Date               Events  TempHighF
# 0     2013-12-21  Rain , Thunderstorm         74
# 1     2013-12-22                              56
# 2     2013-12-23                              58
# 3     2013-12-24                              61
# 4     2013-12-25                              58
# ...          ...                  ...        ...
# 1314  2017-07-27                             103
# 1315  2017-07-28                             105
# 1316  2017-07-29                             107
# 1317  2017-07-30                             106
# 1318  2017-07-31                              99
#
# [1319 rows x 3 columns]

# %% [markdown]
# Selecting rows from a dataframe
# iloc ->searches using index positions
# loc ->seacrhes using index labels

# %%
titanic.iloc[:5]#accessing multiple rows together
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.iloc[[0,3,4,5,7,63,90]]
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 7           899         0       2
# 63          955         1       3
# 90          982         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 7                        Caldwell, Mr. Albert Francis    male  26.0      1
# 63                       Bradley, Miss. Bridget Delia  female  22.0      0
# 90  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...  female  22.0      1
#
#     Parch   Ticket     Fare Cabin Embarked
# ...

# %%
titanic.loc[0:9:,"PassengerId":"Name"]
# Out:
#    PassengerId  Survived  Pclass                                          Name
# 0          892         0       3                              Kelly, Mr. James
# 1          893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2          894         0       2                     Myles, Mr. Thomas Francis
# 3          895         0       3                              Wirz, Mr. Albert
# 4          896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5          897         0       3                    Svensson, Mr. Johan Cervin
# 6          898         1       3                          Connolly, Miss. Kate
# 7          899         0       2                  Caldwell, Mr. Albert Francis
# 8          900         1       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9          901         0       3                       Davies, Mr. John Samuel

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
weather['TempHighF']= weather['TempHighF'].astype('int32')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int32
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
print(((titanic['Age']>=40)& (titanic['Sex']=='female')).value_counts())
# Out:
# False    366
# True      52
# Name: count, dtype: int64

# %%
print(((weather['TempAvgF']>30)& (weather["Events"]=="Rain")).value_counts())
# Out:
# False    1128
# True      191
# Name: count, dtype: int64

# %%
titanic.sort_values('PassengerId',ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 417         1309         0       3
# 416         1308         0       3
# 415         1307         0       3
# 414         1306         1       1
# 413         1305         0       3
# ..           ...       ...     ...
# 4            896         1       3
# 3            895         0       3
# 2            894         0       2
# 1            893         1       3
# 0            892         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 417                      Peter, Master. Michael J    male   NaN      1      1
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# ...

# %%
import numpy as np

# %%
New_data = pd.DataFrame(
    {
        'name':['Aniket','Rupali','Anjali',np.nan,'Malay',np.nan,'Mona',np.nan,'Mishra ji',np.nan],
        'college':['bits','IIT','VIT',np.nan,np.nan,'VIT','DAVV',np.nan,np.nan,'LPU'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]
    }
)

New_data
# Out:
#         name college branch   cgpa  package
# 0     Aniket    bits    eee   6.66      4.0
# 1     Rupali     IIT     it   8.25      5.0
# 2     Anjali     VIT    cse   6.41      6.0
# 3        NaN     NaN    NaN    NaN      NaN
# 4      Malay     NaN     me   5.60      6.0
# 5        NaN     VIT     ce   9.00      7.0
# 6       Mona    DAVV    civ   7.40      8.0
# 7        NaN     NaN    cse  10.00      9.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 9        NaN     LPU    NaN    NaN      NaN

# %%
x = New_data.sort_values('name')
x
# Out:
#         name college branch   cgpa  package
# 0     Aniket    bits    eee   6.66      4.0
# 2     Anjali     VIT    cse   6.41      6.0
# 4      Malay     NaN     me   5.60      6.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 6       Mona    DAVV    civ   7.40      8.0
# 1     Rupali     IIT     it   8.25      5.0
# 3        NaN     NaN    NaN    NaN      NaN
# 5        NaN     VIT     ce   9.00      7.0
# 7        NaN     NaN    cse  10.00      9.0
# 9        NaN     LPU    NaN    NaN      NaN

# %%
print(New_data.sort_values('name',na_position='first',ascending=False,inplace=True))
# Out:
# None

# %%
titanic.sort_values(['Pclass','Name'],ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass  \
# 371         1263         1       1
# 23           915         0       1
# 231         1123         1       1
# 218         1110         1       1
# 407         1299         0       1
# ..           ...       ...     ...
# 8            900         1       3
# 251         1143         0       3
# 57           949         0       3
# 345         1237         1       3
# 392         1284         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 371                     Wilson, Miss. Helen Alice  female  31.0      0      0
# 23                Williams, Mr. Richard Norris II    male  21.0      0      1
# 231                      Willard, Miss. Constance  female  21.0      0      0
# 218  Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1      1
# 407                    Widener, Mr. George Dunton    male  50.0      1      1
# ...

# %%
titanic.set_index('PassengerId',inplace=True)

# %%
titanic.sample(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1028                0       3
# 1153                0       3
# 1055                0       3
# 984                 1       1
# 1071                1       1
# 1260                1       1
# 893                 1       3
# 1087                0       3
# 1008                0       3
# 1279                0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1028                                 Zakarian, Mr. Mapriededer    male  26.5
# 1153                             Nilsson, Mr. August Ferdinand    male  21.0
# 1055                                        Pearce, Mr. Ernest    male   NaN
# 984                       Davidson, Mrs. Thornton (Orian Hays)  female  27.0
# 1071         Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0
# 1260                   Gibson, Mrs. Leonard (Pauline C Boeson)  female  45.0
# ...

# %%
New_data['name'].fillna('------')
# Out:
# 3       ------
# 5       ------
# 7       ------
# 9       ------
# 1       Rupali
# 6         Mona
# 8    Mishra ji
# 4        Malay
# 2       Anjali
# 0       Aniket
# Name: name, dtype: object

# %%
temp = pd.Series([1,1,1,2,3,4,3,3,2,3,4,2,3,3,22])
temp.drop_duplicates(keep='last')
# Out:
# 2      1
# 10     4
# 11     2
# 13     3
# 14    22
# dtype: int64

# %%
temp
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      3
# 5      4
# 6      3
# 7      3
# 8      2
# 9      3
# 10     4
# 11     2
# 12     3
# 13     3
# 14    22
# dtype: int64

# %%
temp.drop(index=[5,6])
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      3
# 7      3
# 8      2
# 9      3
# 10     4
# 11     2
# 12     3
# 13     3
# 14    22
# dtype: int64

# %%
#dropping the entire columns 
New_data.drop(columns=['cgpa','college'])
# Out:
#         name branch  package
# 3        NaN    NaN      NaN
# 5        NaN     ce      7.0
# 7        NaN    cse      9.0
# 9        NaN    NaN      NaN
# 1     Rupali     it      5.0
# 6       Mona    civ      8.0
# 8  Mishra ji    bio      NaN
# 4      Malay     me      6.0
# 2     Anjali    cse      6.0
# 0     Aniket    eee      4.0

# %%
#dropping rows 
New_data.set_index('name').drop(index=['Aniket','Malay'])
# Out:
#           college branch   cgpa  package
# name
# NaN           NaN    NaN    NaN      NaN
# NaN           VIT     ce   9.00      7.0
# NaN           NaN    cse  10.00      9.0
# NaN           LPU    NaN    NaN      NaN
# Rupali        IIT     it   8.25      5.0
# Mona         DAVV    civ   7.40      8.0
# Mishra ji     NaN    bio   7.40      NaN
# Anjali        VIT    cse   6.41      6.0

# %%
filtered_titanim = titanic[((titanic['Fare']>100) & (titanic['Age']<30))]
names_titatic = filtered_titanim['Name']
print(names_titatic)
# Out:
# PassengerId
# 945                            Fortune, Miss. Ethel Flora
# 956                           Ryerson, Master. John Borie
# 1048                                    Bird, Miss. Ellen
# 1076    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 1088                      Spedden, Master. Robert Douglas
# 1144                             Clark, Mr. Walter Miller
# 1164        Clark, Mrs. Walter Miller (Virginia McDowell)
# Name: Name, dtype: object
